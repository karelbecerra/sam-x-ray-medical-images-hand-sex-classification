# %%
from stats import trace
trace.plot('output/trace/xray_masked_gb_run10.csv', print_out=True)
# Out:
# Epochs: 99
# Best epoch (regarding validation accuracy) 93, training accuracy: 0.9820, validation accuracy: 0.9386
# Best epoch (regarding validation loss) 51, training loss: 0.0875, validation loss: 0.1784
