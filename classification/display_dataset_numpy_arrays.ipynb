# %%
# Builds numpy arrays
import os
import sys
import numpy as np
from stats import plots

# Modify this base directory
data_files = [
             "./datasets/original/tst_original_400x300.npz",
             "./datasets/hand_data/tst_masked_400x300.npz",
             "./datasets/enhanced_hand_data/tst_masked_he_400x300.npz",
             "./datasets/hand_mask/tst_masks_400x300.npz",
             "./datasets/background (complement to hand masks)/tst_masked_bg_400x300.npz",
             "./datasets/background_2 (complement to hand mask convex hull)/tst_masked_bg_convex_hull_400x300.npz",
             ]

img_res = (200, 400)
#img_res = (224, 224)

print('Loading  data...')
for data_file in data_files:
  file = np.load(data_file)
  data = file['data']
  metadata = file['md']
  #data = data.astype(np.int16)
  #metadata = metadata.astype(np.int16)

  print('File ', data_file)

  plots.display_sample(data, 10)
# Out:
# Loading  data...
# File  ./datasets/original/tst_original_400x300.npz
# File  ./datasets/hand_data/tst_masked_400x300.npz
# File  ./datasets/enhanced_hand_data/tst_masked_he_400x300.npz
# File  ./datasets/hand_mask/tst_masks_400x300.npz
# File  ./datasets/background (complement to hand masks)/tst_masked_bg_400x300.npz
# File  ./datasets/background_2 (complement to hand mask convex hull)/tst_masked_bg_convex_hull_400x300.npz
